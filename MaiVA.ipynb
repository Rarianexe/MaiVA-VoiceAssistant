# %%
# Name: Rupankar Das
# College Name: National Institiue of Technology, Silchar

# %%
#!pip install pyttsx3
#!pip install wikipedia
#!pip install PyAudio
#!pip install SpeechRecognition
#!pip install Colorama
#!pip install pyjokes

import speech_recognition as sr
import pyttsx3
import datetime
import wikipedia
import webbrowser
import os
import time
import json
import requests
import pyjokes
import colorama
from colorama import Fore

duration=int(4)
print(Fore.BLUE + '[MAI starting...]')
print(Fore.BLACK + '')

engine=pyttsx3.init()
voices=engine.getProperty('voices')
engine.setProperty('voice',voices[1].id)
engine.setProperty('rate',190) 
        
def speak(text):
    engine.say(text)
    engine.runAndWait()
    
def wishMe():
    hour=datetime.datetime.now().hour
    if hour>=0 and hour<12:
        speak("Hello,,,, Good Morning!")
        print("Hello, Good Morning!")
    elif hour>=12 and hour<16:
        speak("Hello,,,, Good Afternoon!")
        print("Hello, Good Afternoon!")
    else:
        speak("Hello,,,, Good Evening!")
        print("Hello, Good Evening!")

def takeCommand():
    r=sr.Recognizer()
    with sr.Microphone() as source:
        print(Fore.GREEN+'\n                PLEASE SPEAK'+Fore.BLACK)
        r.pause_threshold=1
        print(Fore.BLUE+'\n[listening...]'+Fore.BLACK)
        audio=r.record(source,duration=duration)
        print(Fore.RED+'[decoding...]'+Fore.BLACK)
        try:
            statement=r.recognize_google(audio,language='en-In')
            print(f"user said : {statement}\n")
        except Exception as e:
            print(Fore.RED+'[decoding FAILED]'+Fore.BLACK)
            speak("No voice input detected.")
            return "None"
        return statement

speak("MAI starting")
wishMe()
print('This is your very own voice assistant,'+ Fore.GREEN +' MAI'+Fore.BLACK)
speak("This is your very own voice assistant,,,, MAI")

inactive = 0

if __name__=='__main__':
    
    speak(" Tell me,, how can I be of your help ")

    while True:
        speak("Voice Input Active")
        statement = takeCommand().lower()
        if statement==0:
            inactive = inactive + 1
            continue

        if 'is your name' in statement:
            inactive = 0
            speak('My name,, is MAI.')
            print(Fore.GREEN +'My name is MAI.'+Fore.BLACK)
            
        elif "thanks" in statement or "thank" in statement:
            inactive = 0
            speak('Youre welcome!')
            print(Fore.GREEN +'Youre welcome!'+Fore.BLACK)
            
        elif "goodbye" in statement or "bye" in statement or "ok bye" in statement or "stop" in statement or "shutdown" in statement:
            inactive = 0
            speak('Your personal assistant MAI is shutting down.. Bye,, Have a nice day!')
            print(Fore.GREEN +'Your personal assistant MAI is shutting down. Bye, Have a nice day!'+Fore.BLACK)
            break
            
        elif inactive==5:
            speak('No voice input detected for 5 times in a row... User is assumed to be inactive.... Your personal assistant MAI is shutting down.')
            print(Fore.GREEN +'Your personal assistant MAI is shutting down. Bye, Have a nice day!'+Fore.BLACK)
            break
            
        elif "how are you" in statement:
            inactive = 0
            speak('Im great!!! Thank you!')
            print(Fore.GREEN +'Im great! Thank you.'+Fore.BLACK)
            
        elif 'who are you' in statement or 'what can you do' in statement:
            inactive = 0
            speak('I am MAI,, your personal voice assistant. I am programmed to assist people around me .. You can ask me questions like what is your name?, who made you?, what can you do?.etc... or make me do some basic tasks, like opening websites, stating the time and weather,,etc.')
            print(Fore.GREEN +'I am MAI,, your personal voice assistant. I am programmed to assist people around me. You can ask me questions like what is your name?, who made you?, what can you do? etc, or make me do some basic tasks like opening websites, stating the time and weather, etc'+Fore.BLACK)
            time.sleep(1)
            
        elif "who made you" in statement or "who created you" in statement or "who discovered you" in statement:
            inactive = 0
            print(Fore.GREEN +"I was developed by Rupankar Das, from National Institute of Technology, Silchar."+Fore.BLACK)
            speak("I was developed by Rupankar Das, from National Institute of Technology, Silchar.")
            
        elif "joke" in statement or "funny" in statement:
            inactive = 0
            My_joke = pyjokes.get_joke(language="en", category="all")
            print(Fore.GREEN + "Here is a joke for you-\n\n     "+Fore.BLUE+ My_joke +Fore.BLACK)
            speak("Here is a joke for you....." + My_joke)
            time.sleep(3)
            
            print(Fore.GREEN +'Im great! Thank you.'+Fore.BLACK)
            
        elif 'current time' in statement:
            inactive = 0
            strTime=datetime.datetime.now().strftime("%H:%M:%S")
            speak(f"the time is {strTime}")   
            
        elif 'current date' in statement:
            inactive = 0
            strTime=datetime.datetime.now().strftime("%A,, %d %B %Y")
            speak(f"the date is {strTime}") 
            
        elif 'wikipedia' in statement:
            inactive = 0
            speak('Searching Wikipedia...')
            statement =statement.replace("wikipedia", "")
            results = wikipedia.summary(statement, sentences=3)
            speak("According to Wikipedia")
            print(results)
            speak(results)

        elif 'open youtube' in statement:
            inactive = 0
            webbrowser.open_new_tab("https://www.youtube.com/")
            speak("youtube is open now")
            time.sleep(5)
            
        elif 'song' in statement or 'sing' in statement:
            inactive = 0
            webbrowser.open_new_tab("https://www.youtube.com/watch?v=dQw4w9WgXcQ")
            speak("Playing a song for you")
            time.sleep(5)

        elif 'open google' in statement:
            inactive = 0
            webbrowser.open_new_tab("https://www.google.com")
            speak("Google chrome is open now")
            time.sleep(5)
                   
        elif 'search google' in statement:
            inactive = 0
            speak("what do you want to search")
            y=takeCommand()
            webbrowser.open_new("https://www.google.com/search?q="+y)
            time.sleep(5)

        elif 'open gmail' in statement:
            inactive = 0
            webbrowser.open_new_tab("gmail.com")
            speak("Google Mail open now")
            time.sleep(5)
            
        elif 'whatsapp' in statement:
            inactive = 0
            webbrowser.open_new_tab("https://web.whatsapp.com/")
            speak("Whatsapp open now")
            time.sleep(5)

        elif "weather" in statement:
            inactive = 0
            
            api_key='e4b2668db5bbc2f2028ca403b0857a60'

            base_url="https://api.openweathermap.org/data/2.5/weather?"
            speak("whats the city name")
            city_name=takeCommand()
            complete_url=base_url+"appid="+api_key+"&q="+city_name
            response = requests.get(complete_url)
            x=response.json()
            if x["cod"]!="404":
                y=x["main"]
                current_temperature = y["temp"]
                current_humidiy = y["humidity"]
                z = x["weather"]
                weather_description = z[0]["description"]
                speak(" Temperature in kelvin unit is " +
                      str(current_temperature) +
                      "\n humidity in percentage is " +
                      str(current_humidiy) +
                      "\n description  " +
                      str(weather_description))
                print(" Temperature in kelvin unit = " +
                      str(current_temperature) +
                      "\n humidity (in percentage) = " +
                      str(current_humidiy) +
                      "\n description = " +
                      str(weather_description))

            else:
                inactive = 0
                speak(" City Not Found ")
            
            
            
        elif "open stack overflow" in statement:
            inactive = 0
            webbrowser.open_new_tab("https://stackoverflow.com/")
            speak("Here is stackoverflow")
            time.sleep(6)

        elif 'news' in statement:
            inactive = 0
            news = webbrowser.open_new_tab("https://timesofindia.indiatimes.com/home/headlines")
            speak('Here are some headlines from the Times of India,,,Happy reading')
            time.sleep(6)


        elif 'search'  in statement:
            inactive = 0
            statement = statement.replace("search", "")
            webbrowser.open_new_tab(statement)
            time.sleep(5)

time.sleep(5)
# Out:
# [EMILY starting...]
#
# Hello, Good Evening!
# This is your very own voice assistant, EMILY
#
#                 PLEASE SPEAK
#
# [listening...]
# [decoding...]
# user said : what can you do
#
# I am EMILY,, your personal voice assistant. I am programmed to assist people around me. You can ask me questions like what is your name?, who made you?, what can you do? etc, or make me do some basic tasks like opening websites, stating the time and weather, etc
#
#                 PLEASE SPEAK
#
# [listening...]
# [decoding...]
# [decoding FAILED]
